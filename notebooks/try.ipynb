# %%
import xmltojson, json

# %%
from pathlib import Path

# %%
FILES = Path("/home/pwd/Downloads/hotelcenters/")

# %%
files = FILES / "center1.xml"

# %%
o = xmltojson.parse(files.read_text())

# %%
with open("/home/pwd/Downloads/hotelcenters/center1.json", 'w') as f:
    json_string = json.dumps(o, default=lambda o: o.__dict__, sort_keys=True, indent=2)
    f.write(json_string)

# %%
f = json.loads(o)

# %%
f['listings']["listing"]
# Out:
# [{'id': '115',
#   'name': 'Bahia Mar Boutique Hotel',
#   'address': {'@format': 'simple',
#    'component': [{'@name': 'addr1', '#text': 'Bairro 19 de Outubro'},
#     {'@name': 'city', '#text': 'Vilanculos'},
#     {'@name': 'postal_code', '#text': '0000'}]},
#   'country': 'MZ',
#   'latitude': '-21.9721120604417',
#   'longitude': '35.311830609787',
#   'phone': {'@type': 'main', '#text': '+258 293 823 91'},
#   'category': 'hotel',
#   'content': {'image': {'@type': 'photo',
#     '@url': 'https://ecocdn.azureedge.net/cdn/Pictures/Hotel/59ad3904-d047-4b6a-bee1-4e1b5545a6f3-thumb.jpg',
#     '@width': '100',
#     '@height': '75',
#     'link': 'https://ecocdn.azureedge.net/cdn/Pictures/Hotel/59ad3904-d047-4b6a-bee1-4e1b5545a6f3-thumb.jpg',
#     'title': 'Bahia Mar Boutique Hotel',
#     'date': {'@month': '2', '@day': '24', '@year': '2021'}},
#    'attributes': {'website': 'http://www.bahiamarclub.com',
#     'client_attr': [{'@name': 'star_rating', '#text': '4'},
# ...
